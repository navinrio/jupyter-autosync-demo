# %%
print('Hello Autosync')
# Out:
# Hello Autosync

# %%
print("Hello AutoSync test2")
# Out:
# Hello AutoSync test2

# %% [markdown]
# # Agenda
# 1. Day 1
# - Intro
# - Variables
# 2. Day 2
# - Operators
